# %% [markdown]
# # Amazon Recommendation System using Python

# %%
import numpy as np
import pandas as pd
df= pd.read_csv("ratings_Electronics (1).csv")

# %%
df
# Out:
#           AKM1MP6P0OYPR  0132793040  5.0    1365811200
# 0        A2CX7LUOHB2NDG  0321732944  5.0  1.341101e+09
# 1        A2NWSAGRHCP8N5  0439886341  1.0  1.367194e+09
# 2        A2WNBOD3WNDNKT  0439886341  3.0  1.374451e+09
# 3        A1GI0U4ZRJA8WN  0439886341  1.0  1.334707e+09
# 4        A1QGNMC6O1VW39  0511189877  5.0  1.397434e+09
# ...                 ...         ...  ...           ...
# 1235962  A1IQVUN2BX5BE7  B000O5N5AI  5.0  1.368230e+09
# 1235963  A1H4R3VJP7XS3Q  B000O5N5AI  5.0  1.356566e+09
# 1235964    ANJCEW9FF64C  B000O5N5AI  5.0  1.357517e+09
# 1235965   AYTJIBG1TIFHE  B000O5N5AI  5.0  1.370477e+09
# 1235966      AR3OF7K4HO         NaN  NaN           NaN
#
# [1235967 rows x 4 columns]

# %%
df.columns = ['user_id', 'product_id','ratings','timestamp']

# %%
df
# Out:
#                 user_id  product_id  ratings     timestamp
# 0        A2CX7LUOHB2NDG  0321732944      5.0  1.341101e+09
# 1        A2NWSAGRHCP8N5  0439886341      1.0  1.367194e+09
# 2        A2WNBOD3WNDNKT  0439886341      3.0  1.374451e+09
# 3        A1GI0U4ZRJA8WN  0439886341      1.0  1.334707e+09
# 4        A1QGNMC6O1VW39  0511189877      5.0  1.397434e+09
# ...                 ...         ...      ...           ...
# 1235962  A1IQVUN2BX5BE7  B000O5N5AI      5.0  1.368230e+09
# 1235963  A1H4R3VJP7XS3Q  B000O5N5AI      5.0  1.356566e+09
# 1235964    ANJCEW9FF64C  B000O5N5AI      5.0  1.357517e+09
# 1235965   AYTJIBG1TIFHE  B000O5N5AI      5.0  1.370477e+09
# 1235966      AR3OF7K4HO         NaN      NaN           NaN
#
# [1235967 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# user_id       0
# product_id    1
# ratings       1
# timestamp     1
# dtype: int64

# %%
product_grouped =df.groupby('product_id', as_index=False).agg({'ratings':[np.size, np.sum, np.mean]})
# Out:
# <ipython-input-10-561b6a68d3c9>:1: FutureWarning: The provided callable <function sum at 0x7e7d8f542e60> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   product_grouped =df.groupby('product_id', as_index=False).agg({'ratings':[np.size, np.sum, np.mean]})
# <ipython-input-10-561b6a68d3c9>:1: FutureWarning: The provided callable <function mean at 0x7e7d8f543d90> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   product_grouped =df.groupby('product_id', as_index=False).agg({'ratings':[np.size, np.sum, np.mean]})

# %%
product_grouped
# Out:
#        product_id ratings
#                      size     sum      mean
# 0      0321732944       1     5.0  5.000000
# 1      0439886341       3     5.0  1.666667
# 2      0511189877       6    27.0  4.500000
# 3      0528881469      27    77.0  2.851852
# 4      0558835155       1     3.0  3.000000
# ...           ...     ...     ...       ...
# 72422  B000O5LGVS       3    14.0  4.666667
# 72423  B000O5MACW       1     5.0  5.000000
# 72424  B000O5MP4U      62   217.0  3.500000
# 72425  B000O5MS6U       2     4.0  2.000000
# 72426  B000O5N5AI     249  1092.0  4.385542
#
# [72427 rows x 4 columns]

# %%
popular_product=product_grouped.sort_values(('ratings','mean'),ascending=False)

# %%
popular_product
# Out:
#        product_id ratings
#                      size   sum mean
# 0      0321732944       1   5.0  5.0
# 16075  B00008WTAY       1   5.0  5.0
# 45392  B000BERUZI       1   5.0  5.0
# 16037  B00008W887       1   5.0  5.0
# 45394  B000BERV4S       2  10.0  5.0
# ...           ...     ...   ...  ...
# 47775  B000C6WH3U       1   1.0  1.0
# 55078  B000FJ2ILU       2   2.0  1.0
# 66081  B000KL6OUY       1   1.0  1.0
# 35097  B0006Z16N4       1   1.0  1.0
# 12680  B00006I5PV       1   1.0  1.0
#
# [72427 rows x 4 columns]

# %%
product_sum=product_grouped['ratings']['sum'].sum()

# %%
product_sum
# Out:
# 4918534.0

# %%
popular_product['persentage']=product_grouped['ratings']['sum'].div(product_sum)*100

# %%
popular_product
# Out:
#        product_id ratings                    persentage
#                      size      sum      mean
# 30275  B0002L5R78    9487  42204.0  4.448614   0.858061
# 67437  B000LRMS66    8715  41454.0  4.756627   0.842812
# 24438  B0001FTVEK    5345  21418.0  4.007109   0.435455
# 46503  B000BQ7GW8    4275  19465.0  4.553216   0.395748
# 61284  B000I68BD4    4903  17168.0  3.501530   0.349047
# ...           ...     ...      ...       ...        ...
# 10079  B000067TAQ       1      1.0  1.000000   0.000020
# 10075  B000067T4L       1      1.0  1.000000   0.000020
# 5248   B0000501Q8       1      1.0  1.000000   0.000020
# 56130  B000FTI5DK       1      1.0  1.000000   0.000020
# 12680  B00006I5PV       1      1.0  1.000000   0.000020
#
# [72427 rows x 5 columns]

# %%
popular_product=popular_product.sort_values(('persentage'),ascending=False)

# %%
popular_product['Rank']=popular_product['persentage'].rank(ascending=False)

# %%
popular_product
# Out:
#        product_id ratings                    persentage     Rank
#                      size      sum      mean
# 30275  B0002L5R78    9487  42204.0  4.448614   0.858061      1.0
# 67437  B000LRMS66    8715  41454.0  4.756627   0.842812      2.0
# 24438  B0001FTVEK    5345  21418.0  4.007109   0.435455      3.0
# 46503  B000BQ7GW8    4275  19465.0  4.553216   0.395748      4.0
# 61284  B000I68BD4    4903  17168.0  3.501530   0.349047      5.0
# ...           ...     ...      ...       ...        ...      ...
# 10079  B000067TAQ       1      1.0  1.000000   0.000020  70992.0
# 10075  B000067T4L       1      1.0  1.000000   0.000020  70992.0
# 5248   B0000501Q8       1      1.0  1.000000   0.000020  70992.0
# 56130  B000FTI5DK       1      1.0  1.000000   0.000020  70992.0
# 12680  B00006I5PV       1      1.0  1.000000   0.000020  70992.0
#
# [72427 rows x 6 columns]
